# %%
# CONSUMER RECEIVING DATA FROM KAFKA PRODUCER THEN STORE IT TO MONGO DB

# %%
import six
import sys
if sys.version_info >= (3, 12, 0):
    sys.modules['kafka.vendor.six.moves'] = six.moves
import json
from kafka import KafkaConsumer
from pymongo import MongoClient

def insert_data_to_mongodb(data, collection):
    # Insert data into MongoDB collection
    collection.insert_one(data)
    print(f"Inserted record: {data}")

if __name__ == "__main__":
    # Initialize MongoDB connection
    client = MongoClient(("mongodb://admin:admin@localhost:27017/"))
    db = client["kafka_consumer_data_01"]  # database name to store consumer data
    collection = db["kafka_consumer_collection_01"]  # collection name to store consumer data
    consumer = KafkaConsumer("ftde01-project4", bootstrap_servers="localhost")
    print("Starting the consumer")

    for msg in consumer:
        data = json.loads(msg.value)
        if isinstance(data, list):
            for record in data:
                insert_data_to_mongodb(record, collection)
        else:
            insert_data_to_mongodb(data, collection)

client.close()
# Out:
# Starting the consumer
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9839.64, 'nameOrig': 'C1231006815', 'newbalanceOrig': 160296.36, 'nameDest': 'M1979787155', 'newbalanceDest': 0.0, '_id': ObjectId('66910e0ae44630bf9f92c6bd')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1864.28, 'nameOrig': 'C1666544295', 'newbalanceOrig': 19384.72, 'nameDest': 'M2044282225', 'newbalanceDest': 0.0, '_id': ObjectId('66910e0fe44630bf9f92c6be')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 181.0, 'nameOrig': 'C1305486145', 'newbalanceOrig': 0.0, 'nameDest': 'C553264065', 'newbalanceDest': 0.0, '_id': ObjectId('66910e14e44630bf9f92c6bf')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 181.0, 'nameOrig': 'C840083671', 'newbalanceOrig': 0.0, 'nameDest': 'C38997010', 'newbalanceDest': 0.0, '_id': ObjectId('66910e19e44630bf9f92c6c0')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 11668.14, 'nameOrig': 'C2048537720', 'newbalanceOrig': 29885.86, 'nameDest': 'M1230701703', 'newbalanceDest': 0.0, '_id': ObjectId('66910e1ee44630bf9f92c6c1')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7817.71, 'nameOrig': 'C90045638', 'newbalanceOrig': 46042.29, 'nameDest': 'M573487274', 'newbalanceDest': 0.0, '_id': ObjectId('66910e23e44630bf9f92c6c2')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7107.77, 'nameOrig': 'C154988899', 'newbalanceOrig': 176087.23, 'nameDest': 'M408069119', 'newbalanceDest': 0.0, '_id': ObjectId('66910e28e44630bf9f92c6c3')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7861.64, 'nameOrig': 'C1912850431', 'newbalanceOrig': 168225.59, 'nameDest': 'M633326333', 'newbalanceDest': 0.0, '_id': ObjectId('66910e2de44630bf9f92c6c4')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4024.36, 'nameOrig': 'C1265012928', 'newbalanceOrig': 0.0, 'nameDest': 'M1176932104', 'newbalanceDest': 0.0, '_id': ObjectId('66910e32e44630bf9f92c6c5')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 5337.77, 'nameOrig': 'C712410124', 'newbalanceOrig': 36382.23, 'nameDest': 'C195600860', 'newbalanceDest': 40348.79, '_id': ObjectId('66910e37e44630bf9f92c6c6')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 9644.94, 'nameOrig': 'C1900366749', 'newbalanceOrig': 0.0, 'nameDest': 'C997608398', 'newbalanceDest': 157982.12, '_id': ObjectId('66910e3ce44630bf9f92c6c7')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3099.97, 'nameOrig': 'C249177573', 'newbalanceOrig': 17671.03, 'nameDest': 'M2096539129', 'newbalanceDest': 0.0, '_id': ObjectId('66910e41e44630bf9f92c6c8')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2560.74, 'nameOrig': 'C1648232591', 'newbalanceOrig': 2509.26, 'nameDest': 'M972865270', 'newbalanceDest': 0.0, '_id': ObjectId('66910e46e44630bf9f92c6c9')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 11633.76, 'nameOrig': 'C1716932897', 'newbalanceOrig': 0.0, 'nameDest': 'M801569151', 'newbalanceDest': 0.0, '_id': ObjectId('66910e4be44630bf9f92c6ca')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4098.78, 'nameOrig': 'C1026483832', 'newbalanceOrig': 499165.22, 'nameDest': 'M1635378213', 'newbalanceDest': 0.0, '_id': ObjectId('66910e50e44630bf9f92c6cb')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 229133.94, 'nameOrig': 'C905080434', 'newbalanceOrig': 0.0, 'nameDest': 'C476402209', 'newbalanceDest': 51513.44, '_id': ObjectId('66910e55e44630bf9f92c6cc')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1563.82, 'nameOrig': 'C761750706', 'newbalanceOrig': 0.0, 'nameDest': 'M1731217984', 'newbalanceDest': 0.0, '_id': ObjectId('66910e5ae44630bf9f92c6cd')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1157.86, 'nameOrig': 'C1237762639', 'newbalanceOrig': 19998.14, 'nameDest': 'M1877062907', 'newbalanceDest': 0.0, '_id': ObjectId('66910e5fe44630bf9f92c6ce')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 671.64, 'nameOrig': 'C2033524545', 'newbalanceOrig': 14451.36, 'nameDest': 'M473053293', 'newbalanceDest': 0.0, '_id': ObjectId('66910e64e44630bf9f92c6cf')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 215310.3, 'nameOrig': 'C1670993182', 'newbalanceOrig': 0.0, 'nameDest': 'C1100439041', 'newbalanceDest': 0.0, '_id': ObjectId('66910e69e44630bf9f92c6d0')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1373.43, 'nameOrig': 'C20804602', 'newbalanceOrig': 12480.57, 'nameDest': 'M1344519051', 'newbalanceDest': 0.0, '_id': ObjectId('66910e6ee44630bf9f92c6d1')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 9302.79, 'nameOrig': 'C1566511282', 'newbalanceOrig': 1996.21, 'nameDest': 'C1973538135', 'newbalanceDest': 16896.7, '_id': ObjectId('66910e73e44630bf9f92c6d2')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 1065.41, 'nameOrig': 'C1959239586', 'newbalanceOrig': 751.59, 'nameDest': 'C515132998', 'newbalanceDest': 0.0, '_id': ObjectId('66910e78e44630bf9f92c6d3')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3876.41, 'nameOrig': 'C504336483', 'newbalanceOrig': 63975.59, 'nameDest': 'M1404932042', 'newbalanceDest': 0.0, '_id': ObjectId('66910e7de44630bf9f92c6d4')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 311685.89, 'nameOrig': 'C1984094095', 'newbalanceOrig': 0.0, 'nameDest': 'C932583850', 'newbalanceDest': 2719172.89, '_id': ObjectId('66910e82e44630bf9f92c6d5')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 6061.13, 'nameOrig': 'C1043358826', 'newbalanceOrig': 0.0, 'nameDest': 'M1558079303', 'newbalanceDest': 0.0, '_id': ObjectId('66910e87e44630bf9f92c6d6')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9478.39, 'nameOrig': 'C1671590089', 'newbalanceOrig': 107015.61, 'nameDest': 'M58488213', 'newbalanceDest': 0.0, '_id': ObjectId('66910e8ce44630bf9f92c6d7')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8009.09, 'nameOrig': 'C1053967012', 'newbalanceOrig': 2958.91, 'nameDest': 'M295304806', 'newbalanceDest': 0.0, '_id': ObjectId('66910e91e44630bf9f92c6d8')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8901.99, 'nameOrig': 'C1632497828', 'newbalanceOrig': 0.0, 'nameDest': 'M33419717', 'newbalanceDest': 0.0, '_id': ObjectId('66910e96e44630bf9f92c6d9')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9920.52, 'nameOrig': 'C764826684', 'newbalanceOrig': 0.0, 'nameDest': 'M1940055334', 'newbalanceDest': 0.0, '_id': ObjectId('66910e9be44630bf9f92c6da')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3448.92, 'nameOrig': 'C2103763750', 'newbalanceOrig': 0.0, 'nameDest': 'M335107734', 'newbalanceDest': 0.0, '_id': ObjectId('66910ea0e44630bf9f92c6db')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4206.84, 'nameOrig': 'C215078753', 'newbalanceOrig': 0.0, 'nameDest': 'M1757317128', 'newbalanceDest': 0.0, '_id': ObjectId('66910ea5e44630bf9f92c6dc')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5885.56, 'nameOrig': 'C840514538', 'newbalanceOrig': 0.0, 'nameDest': 'M1804441305', 'newbalanceDest': 0.0, '_id': ObjectId('66910eaae44630bf9f92c6dd')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5307.88, 'nameOrig': 'C1768242710', 'newbalanceOrig': 0.0, 'nameDest': 'M1971783162', 'newbalanceDest': 0.0, '_id': ObjectId('66910eafe44630bf9f92c6de')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5031.22, 'nameOrig': 'C247113419', 'newbalanceOrig': 0.0, 'nameDest': 'M151442075', 'newbalanceDest': 0.0, '_id': ObjectId('66910eb4e44630bf9f92c6df')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 24213.67, 'nameOrig': 'C1238616099', 'newbalanceOrig': 0.0, 'nameDest': 'M70695990', 'newbalanceDest': 0.0, '_id': ObjectId('66910eb9e44630bf9f92c6e0')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8603.42, 'nameOrig': 'C1608633989', 'newbalanceOrig': 0.0, 'nameDest': 'M1615617512', 'newbalanceDest': 0.0, '_id': ObjectId('66910ebee44630bf9f92c6e1')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2791.42, 'nameOrig': 'C923341586', 'newbalanceOrig': 297689.58, 'nameDest': 'M107994825', 'newbalanceDest': 0.0, '_id': ObjectId('66910ec3e44630bf9f92c6e2')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7413.54, 'nameOrig': 'C1470868839', 'newbalanceOrig': 290276.03, 'nameDest': 'M1426725223', 'newbalanceDest': 0.0, '_id': ObjectId('66910ec8e44630bf9f92c6e3')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3295.19, 'nameOrig': 'C711197015', 'newbalanceOrig': 230337.81, 'nameDest': 'M1384454980', 'newbalanceDest': 0.0, '_id': ObjectId('66910ecde44630bf9f92c6e4')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1684.81, 'nameOrig': 'C1481594086', 'newbalanceOrig': 0.0, 'nameDest': 'M1569435561', 'newbalanceDest': 0.0, '_id': ObjectId('66910ed2e44630bf9f92c6e5')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 5758.59, 'nameOrig': 'C1466917878', 'newbalanceOrig': 26845.41, 'nameDest': 'C1297685781', 'newbalanceDest': 16997.22, '_id': ObjectId('66910ed7e44630bf9f92c6e6')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 110414.71, 'nameOrig': 'C768216420', 'newbalanceOrig': 0.0, 'nameDest': 'C1509514333', 'newbalanceDest': 2415.16, '_id': ObjectId('66910edce44630bf9f92c6e7')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7823.46, 'nameOrig': 'C260084831', 'newbalanceOrig': 0.0, 'nameDest': 'M267814113', 'newbalanceDest': 0.0, '_id': ObjectId('66910ee1e44630bf9f92c6e8')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5086.48, 'nameOrig': 'C598357562', 'newbalanceOrig': 0.0, 'nameDest': 'M1593224710', 'newbalanceDest': 0.0, '_id': ObjectId('66910ee6e44630bf9f92c6e9')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5281.48, 'nameOrig': 'C1440738283', 'newbalanceOrig': 146737.52, 'nameDest': 'M1849015357', 'newbalanceDest': 0.0, '_id': ObjectId('66910eebe44630bf9f92c6ea')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 13875.98, 'nameOrig': 'C484199463', 'newbalanceOrig': 1942.02, 'nameDest': 'M2008106788', 'newbalanceDest': 0.0, '_id': ObjectId('66910ef0e44630bf9f92c6eb')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 56953.9, 'nameOrig': 'C1570470538', 'newbalanceOrig': 0.0, 'nameDest': 'C824009085', 'newbalanceDest': 64106.18, '_id': ObjectId('66910ef5e44630bf9f92c6ec')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 5346.89, 'nameOrig': 'C512549200', 'newbalanceOrig': 0.0, 'nameDest': 'C248609774', 'newbalanceDest': 6453430.91, '_id': ObjectId('66910efae44630bf9f92c6ed')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2204.04, 'nameOrig': 'C1615801298', 'newbalanceOrig': 0.0, 'nameDest': 'M490391704', 'newbalanceDest': 0.0, '_id': ObjectId('66910effe44630bf9f92c6ee')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2641.47, 'nameOrig': 'C460570271', 'newbalanceOrig': 20411.53, 'nameDest': 'M1653361344', 'newbalanceDest': 0.0, '_id': ObjectId('66910f04e44630bf9f92c6ef')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 23261.3, 'nameOrig': 'C2072313080', 'newbalanceOrig': 0.0, 'nameDest': 'C2001112025', 'newbalanceDest': 0.0, '_id': ObjectId('66910f09e44630bf9f92c6f0')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2330.64, 'nameOrig': 'C816944408', 'newbalanceOrig': 201212.36, 'nameDest': 'M909132503', 'newbalanceDest': 0.0, '_id': ObjectId('66910f0ee44630bf9f92c6f1')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1614.64, 'nameOrig': 'C912966811', 'newbalanceOrig': 39661.36, 'nameDest': 'M1792384402', 'newbalanceDest': 0.0, '_id': ObjectId('66910f13e44630bf9f92c6f2')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9164.71, 'nameOrig': 'C1458621573', 'newbalanceOrig': 38071.06, 'nameDest': 'M1658980982', 'newbalanceDest': 0.0, '_id': ObjectId('66910f18e44630bf9f92c6f3')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2970.97, 'nameOrig': 'C46941357', 'newbalanceOrig': 35100.09, 'nameDest': 'M1152606315', 'newbalanceDest': 0.0, '_id': ObjectId('66910f1de44630bf9f92c6f4')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 38.66, 'nameOrig': 'C343345308', 'newbalanceOrig': 16135.34, 'nameDest': 'M1714688478', 'newbalanceDest': 0.0, '_id': ObjectId('66910f22e44630bf9f92c6f5')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2252.44, 'nameOrig': 'C104716441', 'newbalanceOrig': 0.0, 'nameDest': 'M1506951181', 'newbalanceDest': 0.0, '_id': ObjectId('66910f27e44630bf9f92c6f6')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 62610.8, 'nameOrig': 'C1976401987', 'newbalanceOrig': 16503.2, 'nameDest': 'C1937962514', 'newbalanceDest': 8383.29, '_id': ObjectId('66910f2ce44630bf9f92c6f7')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 5529.13, 'nameOrig': 'C867288517', 'newbalanceOrig': 3017.87, 'nameDest': 'C242131142', 'newbalanceDest': 0.0, '_id': ObjectId('66910f31e44630bf9f92c6f8')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 82940.31, 'nameOrig': 'C1528834618', 'newbalanceOrig': 0.0, 'nameDest': 'C476800120', 'newbalanceDest': 49864.36, '_id': ObjectId('66910f36e44630bf9f92c6f9')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 4510.22, 'nameOrig': 'C280615803', 'newbalanceOrig': 5745.78, 'nameDest': 'C1254526270', 'newbalanceDest': 0.0, '_id': ObjectId('66910f3be44630bf9f92c6fa')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 8727.74, 'nameOrig': 'C166694583', 'newbalanceOrig': 874042.26, 'nameDest': 'C1129670968', 'newbalanceDest': 0.0, '_id': ObjectId('66910f40e44630bf9f92c6fb')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2599.46, 'nameOrig': 'C885910946', 'newbalanceOrig': 871442.79, 'nameDest': 'M1860591867', 'newbalanceDest': 0.0, '_id': ObjectId('66910f45e44630bf9f92c6fc')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 4874.49, 'nameOrig': 'C811207775', 'newbalanceOrig': 0.0, 'nameDest': 'C1971489295', 'newbalanceDest': 0.0, '_id': ObjectId('66910f4ae44630bf9f92c6fd')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 6440.78, 'nameOrig': 'C1161148117', 'newbalanceOrig': 0.0, 'nameDest': 'M516875052', 'newbalanceDest': 0.0, '_id': ObjectId('66910f4fe44630bf9f92c6fe')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4910.14, 'nameOrig': 'C1131592118', 'newbalanceOrig': 36640.86, 'nameDest': 'M589987187', 'newbalanceDest': 0.0, '_id': ObjectId('66910f54e44630bf9f92c6ff')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 6444.64, 'nameOrig': 'C1262609629', 'newbalanceOrig': 5574.36, 'nameDest': 'M587180314', 'newbalanceDest': 0.0, '_id': ObjectId('66910f59e44630bf9f92c700')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 5149.66, 'nameOrig': 'C1955990522', 'newbalanceOrig': 0.0, 'nameDest': 'C1330106945', 'newbalanceDest': 24044.18, '_id': ObjectId('66910f5ee44630bf9f92c701')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 7292.16, 'nameOrig': 'C69673470', 'newbalanceOrig': 209534.84, 'nameDest': 'M1082411691', 'newbalanceDest': 0.0, '_id': ObjectId('66910f63e44630bf9f92c702')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 47458.86, 'nameOrig': 'C527211736', 'newbalanceOrig': 162075.98, 'nameDest': 'C2096057945', 'newbalanceDest': 0.0, '_id': ObjectId('66910f68e44630bf9f92c703')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 136872.92, 'nameOrig': 'C1533123860', 'newbalanceOrig': 25203.05, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('66910f6de44630bf9f92c704')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 94253.33, 'nameOrig': 'C1718906711', 'newbalanceOrig': 0.0, 'nameDest': 'C977993101', 'newbalanceDest': 965870.05, '_id': ObjectId('66910f72e44630bf9f92c705')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2998.04, 'nameOrig': 'C71802912', 'newbalanceOrig': 9031.96, 'nameDest': 'M2134271532', 'newbalanceDest': 0.0, '_id': ObjectId('66910f77e44630bf9f92c706')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3454.08, 'nameOrig': 'C686349795', 'newbalanceOrig': 5577.88, 'nameDest': 'M1831010686', 'newbalanceDest': 0.0, '_id': ObjectId('66910f7ce44630bf9f92c707')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4316.2, 'nameOrig': 'C1423768154', 'newbalanceOrig': 6682.8, 'nameDest': 'M404222443', 'newbalanceDest': 0.0, '_id': ObjectId('66910f81e44630bf9f92c708')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2131.84, 'nameOrig': 'C1987977423', 'newbalanceOrig': 0.0, 'nameDest': 'M61073295', 'newbalanceDest': 0.0, '_id': ObjectId('66910f86e44630bf9f92c709')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 12986.61, 'nameOrig': 'C807322507', 'newbalanceOrig': 10363.39, 'nameDest': 'M396485834', 'newbalanceDest': 0.0, '_id': ObjectId('66910f8be44630bf9f92c70a')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 42712.39, 'nameOrig': 'C283039401', 'newbalanceOrig': 0.0, 'nameDest': 'C1330106945', 'newbalanceDest': 24044.18, '_id': ObjectId('66910f90e44630bf9f92c70b')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 77957.68, 'nameOrig': 'C207471778', 'newbalanceOrig': 0.0, 'nameDest': 'C1761291320', 'newbalanceDest': 22233.65, '_id': ObjectId('66910f95e44630bf9f92c70c')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 17231.46, 'nameOrig': 'C1243171897', 'newbalanceOrig': 0.0, 'nameDest': 'C783286238', 'newbalanceDest': 0.0, '_id': ObjectId('66910f9ae44630bf9f92c70d')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 78766.03, 'nameOrig': 'C1376151044', 'newbalanceOrig': 0.0, 'nameDest': 'C1749186397', 'newbalanceDest': 277515.05, '_id': ObjectId('66910f9fe44630bf9f92c70e')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 224606.64, 'nameOrig': 'C873175411', 'newbalanceOrig': 0.0, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('66910fa4e44630bf9f92c70f')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 125872.53, 'nameOrig': 'C1443967876', 'newbalanceOrig': 0.0, 'nameDest': 'C392292416', 'newbalanceDest': 3420103.09, '_id': ObjectId('66910fa9e44630bf9f92c710')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 379856.23, 'nameOrig': 'C1449772539', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66910faee44630bf9f92c711')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 1505626.01, 'nameOrig': 'C926859124', 'newbalanceOrig': 0.0, 'nameDest': 'C665576141', 'newbalanceDest': 5515763.34, '_id': ObjectId('66910fb3e44630bf9f92c712')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 554026.99, 'nameOrig': 'C1603696865', 'newbalanceOrig': 0.0, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('66910fb8e44630bf9f92c713')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 147543.1, 'nameOrig': 'C12905860', 'newbalanceOrig': 0.0, 'nameDest': 'C1359044626', 'newbalanceDest': 16518.36, '_id': ObjectId('66910fbde44630bf9f92c714')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 761507.39, 'nameOrig': 'C412788346', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66910fc2e44630bf9f92c715')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 1429051.47, 'nameOrig': 'C1520267010', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66910fc7e44630bf9f92c716')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 358831.92, 'nameOrig': 'C908084672', 'newbalanceOrig': 0.0, 'nameDest': 'C392292416', 'newbalanceDest': 3420103.09, '_id': ObjectId('66910fcce44630bf9f92c717')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 367768.4, 'nameOrig': 'C288306765', 'newbalanceOrig': 0.0, 'nameDest': 'C1359044626', 'newbalanceDest': 16518.36, '_id': ObjectId('66910fd1e44630bf9f92c718')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 209711.11, 'nameOrig': 'C1556867940', 'newbalanceOrig': 0.0, 'nameDest': 'C1509514333', 'newbalanceDest': 2415.16, '_id': ObjectId('66910fd6e44630bf9f92c719')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 583848.46, 'nameOrig': 'C1839168128', 'newbalanceOrig': 0.0, 'nameDest': 'C1286084959', 'newbalanceDest': 2107778.11, '_id': ObjectId('66910fdbe44630bf9f92c71a')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 1724887.05, 'nameOrig': 'C1495608502', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66910fe0e44630bf9f92c71b')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 710544.77, 'nameOrig': 'C835773569', 'newbalanceOrig': 0.0, 'nameDest': 'C1359044626', 'newbalanceDest': 16518.36, '_id': ObjectId('66910fe5e44630bf9f92c71c')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 581294.26, 'nameOrig': 'C843299092', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66910feae44630bf9f92c71d')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 11996.58, 'nameOrig': 'C605982374', 'newbalanceOrig': 0.0, 'nameDest': 'C1225616405', 'newbalanceDest': 0.0, '_id': ObjectId('66910fefe44630bf9f92c71e')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2875.1, 'nameOrig': 'C1412322831', 'newbalanceOrig': 12567.9, 'nameDest': 'M1651262695', 'newbalanceDest': 0.0, '_id': ObjectId('66910ff4e44630bf9f92c71f')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8586.98, 'nameOrig': 'C1305004711', 'newbalanceOrig': 0.0, 'nameDest': 'M494077446', 'newbalanceDest': 0.0, '_id': ObjectId('66910ff9e44630bf9f92c720')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 871.75, 'nameOrig': 'C1003206025', 'newbalanceOrig': 18997.25, 'nameDest': 'M989889899', 'newbalanceDest': 0.0, '_id': ObjectId('66910ffee44630bf9f92c721')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1035.36, 'nameOrig': 'C806813022', 'newbalanceOrig': 70600.64, 'nameDest': 'M902860396', 'newbalanceDest': 0.0, '_id': ObjectId('66911003e44630bf9f92c722')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1063.53, 'nameOrig': 'C1406206626', 'newbalanceOrig': 82020.47, 'nameDest': 'M1816522350', 'newbalanceDest': 0.0, '_id': ObjectId('66911008e44630bf9f92c723')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1019.9, 'nameOrig': 'C1799230133', 'newbalanceOrig': 203217.1, 'nameDest': 'M1521238608', 'newbalanceDest': 0.0, '_id': ObjectId('6691100de44630bf9f92c724')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4059.38, 'nameOrig': 'C20156341', 'newbalanceOrig': 22244.62, 'nameDest': 'M1111897955', 'newbalanceDest': 0.0, '_id': ObjectId('66911012e44630bf9f92c725')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1876.44, 'nameOrig': 'C1509309988', 'newbalanceOrig': 0.0, 'nameDest': 'M1643141512', 'newbalanceDest': 0.0, '_id': ObjectId('66911017e44630bf9f92c726')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 28404.6, 'nameOrig': 'C2091072548', 'newbalanceOrig': 0.0, 'nameDest': 'C1282788025', 'newbalanceDest': 0.0, '_id': ObjectId('6691101ce44630bf9f92c727')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 75405.1, 'nameOrig': 'C263053820', 'newbalanceOrig': 0.0, 'nameDest': 'C1870252780', 'newbalanceDest': 46462.23, '_id': ObjectId('66911021e44630bf9f92c728')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 50101.88, 'nameOrig': 'C1740826931', 'newbalanceOrig': 0.0, 'nameDest': 'C97730845', 'newbalanceDest': 9940339.29, '_id': ObjectId('66911026e44630bf9f92c729')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 14121.82, 'nameOrig': 'C69062746', 'newbalanceOrig': 0.0, 'nameDest': 'C100555887', 'newbalanceDest': 10963.66, '_id': ObjectId('6691102be44630bf9f92c72a')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 78292.91, 'nameOrig': 'C1631227617', 'newbalanceOrig': 0.0, 'nameDest': 'C1983747920', 'newbalanceDest': 95508.95, '_id': ObjectId('66911030e44630bf9f92c72b')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 176149.9, 'nameOrig': 'C24650043', 'newbalanceOrig': 0.0, 'nameDest': 'C736709391', 'newbalanceDest': 46820.71, '_id': ObjectId('66911035e44630bf9f92c72c')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 212228.35, 'nameOrig': 'C1896074070', 'newbalanceOrig': 0.0, 'nameDest': 'C401424608', 'newbalanceDest': 1178808.14, '_id': ObjectId('6691103ae44630bf9f92c72d')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 85423.63, 'nameOrig': 'C460741164', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('6691103fe44630bf9f92c72e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 11648.5, 'nameOrig': 'C781091365', 'newbalanceOrig': 0.0, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('66911044e44630bf9f92c72f')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 6165.58, 'nameOrig': 'C1858015030', 'newbalanceOrig': 14759.42, 'nameDest': 'M25764044', 'newbalanceDest': 0.0, '_id': ObjectId('66911049e44630bf9f92c730')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3705.83, 'nameOrig': 'C671596011', 'newbalanceOrig': 38197.63, 'nameDest': 'M1925352804', 'newbalanceDest': 0.0, '_id': ObjectId('6691104ee44630bf9f92c731')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 419801.4, 'nameOrig': 'C1687354037', 'newbalanceOrig': 0.0, 'nameDest': 'C33524623', 'newbalanceDest': 1517262.16, '_id': ObjectId('66911053e44630bf9f92c732')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 335416.51, 'nameOrig': 'C743778731', 'newbalanceOrig': 0.0, 'nameDest': 'C575335780', 'newbalanceDest': 52415.15, '_id': ObjectId('66911058e44630bf9f92c733')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3372.29, 'nameOrig': 'C967323951', 'newbalanceOrig': 38025.71, 'nameDest': 'M1600594643', 'newbalanceDest': 0.0, '_id': ObjectId('6691105de44630bf9f92c734')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 661.43, 'nameOrig': 'C743648472', 'newbalanceOrig': 13416.57, 'nameDest': 'M692998280', 'newbalanceDest': 0.0, '_id': ObjectId('66911062e44630bf9f92c735')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 864.68, 'nameOrig': 'C1368862151', 'newbalanceOrig': 68971.32, 'nameDest': 'C20671747', 'newbalanceDest': 43691.09, '_id': ObjectId('66911067e44630bf9f92c736')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1203.44, 'nameOrig': 'C922807452', 'newbalanceOrig': 28737.56, 'nameDest': 'M33563464', 'newbalanceDest': 0.0, '_id': ObjectId('6691106ce44630bf9f92c737')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 330757.04, 'nameOrig': 'C1494346128', 'newbalanceOrig': 0.0, 'nameDest': 'C564160838', 'newbalanceDest': 1254956.07, '_id': ObjectId('66911071e44630bf9f92c738')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1915.43, 'nameOrig': 'C822087264', 'newbalanceOrig': 9534.57, 'nameDest': 'M30699728', 'newbalanceDest': 0.0, '_id': ObjectId('66911076e44630bf9f92c739')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8.73, 'nameOrig': 'C38603201', 'newbalanceOrig': 81304.27, 'nameDest': 'M1422273905', 'newbalanceDest': 0.0, '_id': ObjectId('6691107be44630bf9f92c73a')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 3058.8, 'nameOrig': 'C1694784135', 'newbalanceOrig': 15079.2, 'nameDest': 'C801197928', 'newbalanceDest': 8917.54, '_id': ObjectId('66911080e44630bf9f92c73b')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5154.97, 'nameOrig': 'C1207231495', 'newbalanceOrig': 4321.03, 'nameDest': 'M756936249', 'newbalanceDest': 0.0, '_id': ObjectId('66911085e44630bf9f92c73c')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5213.25, 'nameOrig': 'C1221981006', 'newbalanceOrig': 31166.75, 'nameDest': 'M264394929', 'newbalanceDest': 0.0, '_id': ObjectId('6691108ae44630bf9f92c73d')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5392.75, 'nameOrig': 'C1878413714', 'newbalanceOrig': 45364.25, 'nameDest': 'M769132147', 'newbalanceDest': 0.0, '_id': ObjectId('6691108fe44630bf9f92c73e')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 25.12, 'nameOrig': 'C1257299717', 'newbalanceOrig': 61637.88, 'nameDest': 'M1474957626', 'newbalanceDest': 0.0, '_id': ObjectId('66911094e44630bf9f92c73f')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 17150.89, 'nameOrig': 'C181252244', 'newbalanceOrig': 44486.99, 'nameDest': 'M1733022752', 'newbalanceDest': 0.0, '_id': ObjectId('66911099e44630bf9f92c740')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 679502.24, 'nameOrig': 'C722417467', 'newbalanceOrig': 0.0, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('6691109ee44630bf9f92c741')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 177652.91, 'nameOrig': 'C753631393', 'newbalanceOrig': 0.0, 'nameDest': 'C716157500', 'newbalanceDest': 4894.45, '_id': ObjectId('669110a3e44630bf9f92c742')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5443.26, 'nameOrig': 'C1262869688', 'newbalanceOrig': 231553.74, 'nameDest': 'M1914108708', 'newbalanceDest': 0.0, '_id': ObjectId('669110a8e44630bf9f92c743')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 244.87, 'nameOrig': 'C544386226', 'newbalanceOrig': 257733.62, 'nameDest': 'M1357700757', 'newbalanceDest': 0.0, '_id': ObjectId('669110ade44630bf9f92c744')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8281.57, 'nameOrig': 'C900298796', 'newbalanceOrig': 249452.05, 'nameDest': 'M1889757798', 'newbalanceDest': 0.0, '_id': ObjectId('669110b2e44630bf9f92c745')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1175.59, 'nameOrig': 'C1166106620', 'newbalanceOrig': 19333.41, 'nameDest': 'M1932470703', 'newbalanceDest': 0.0, '_id': ObjectId('669110b7e44630bf9f92c746')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1097.74, 'nameOrig': 'C221861886', 'newbalanceOrig': 23768.26, 'nameDest': 'M1713568869', 'newbalanceDest': 0.0, '_id': ObjectId('669110bce44630bf9f92c747')}
# Inserted record: {'step': 1, 'type': 'TRANSFER', 'amount': 184986.8, 'nameOrig': 'C697508322', 'newbalanceOrig': 0.0, 'nameDest': 'C1688019098', 'newbalanceDest': 97263.78, '_id': ObjectId('669110c1e44630bf9f92c748')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 1718.29, 'nameOrig': 'C603658030', 'newbalanceOrig': 116092.71, 'nameDest': 'M1689924104', 'newbalanceDest': 0.0, '_id': ObjectId('669110c6e44630bf9f92c749')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3671.32, 'nameOrig': 'C361380654', 'newbalanceOrig': 96422.68, 'nameDest': 'M631673932', 'newbalanceDest': 0.0, '_id': ObjectId('669110cbe44630bf9f92c74a')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 3580.26, 'nameOrig': 'C1579132337', 'newbalanceOrig': 0.0, 'nameDest': 'C1321640594', 'newbalanceDest': 18910.85, '_id': ObjectId('669110d0e44630bf9f92c74b')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 8550.9, 'nameOrig': 'C1795225096', 'newbalanceOrig': 31509.1, 'nameDest': 'M790094605', 'newbalanceDest': 0.0, '_id': ObjectId('669110d5e44630bf9f92c74c')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9753.55, 'nameOrig': 'C1048712791', 'newbalanceOrig': 51075.45, 'nameDest': 'M487792155', 'newbalanceDest': 0.0, '_id': ObjectId('669110dae44630bf9f92c74d')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 3026.98, 'nameOrig': 'C1909398279', 'newbalanceOrig': 28112.02, 'nameDest': 'M1632670136', 'newbalanceDest': 0.0, '_id': ObjectId('669110dfe44630bf9f92c74e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 467177.03, 'nameOrig': 'C1338905451', 'newbalanceOrig': 0.0, 'nameDest': 'C1170794006', 'newbalanceDest': 22190.99, '_id': ObjectId('669110e4e44630bf9f92c74f')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 3875.99, 'nameOrig': 'C1252540239', 'newbalanceOrig': 255262.01, 'nameDest': 'C1509514333', 'newbalanceDest': 2415.16, '_id': ObjectId('669110e9e44630bf9f92c750')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2148.89, 'nameOrig': 'C1136005694', 'newbalanceOrig': 29064.11, 'nameDest': 'M638486177', 'newbalanceDest': 0.0, '_id': ObjectId('669110eee44630bf9f92c751')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 466.97, 'nameOrig': 'C426019904', 'newbalanceOrig': 79563.03, 'nameDest': 'M314411620', 'newbalanceDest': 0.0, '_id': ObjectId('669110f3e44630bf9f92c752')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 154139.72, 'nameOrig': 'C1642679791', 'newbalanceOrig': 0.0, 'nameDest': 'C564160838', 'newbalanceDest': 1254956.07, '_id': ObjectId('669110f8e44630bf9f92c753')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 82685.93, 'nameOrig': 'C855700733', 'newbalanceOrig': 0.0, 'nameDest': 'C392292416', 'newbalanceDest': 3420103.09, '_id': ObjectId('669110fde44630bf9f92c754')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 83857.23, 'nameOrig': 'C247162961', 'newbalanceOrig': 0.0, 'nameDest': 'C1297685781', 'newbalanceDest': 16997.22, '_id': ObjectId('66911102e44630bf9f92c755')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 99109.77, 'nameOrig': 'C1890266440', 'newbalanceOrig': 0.0, 'nameDest': 'C1297685781', 'newbalanceDest': 16997.22, '_id': ObjectId('66911107e44630bf9f92c756')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 187726.67, 'nameOrig': 'C1527152775', 'newbalanceOrig': 0.0, 'nameDest': 'C747464370', 'newbalanceDest': 1567434.81, '_id': ObjectId('6691110ce44630bf9f92c757')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 281339.92, 'nameOrig': 'C1863655430', 'newbalanceOrig': 0.0, 'nameDest': 'C1509514333', 'newbalanceDest': 2415.16, '_id': ObjectId('66911111e44630bf9f92c758')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 186447.51, 'nameOrig': 'C976827477', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66911116e44630bf9f92c759')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 81029.86, 'nameOrig': 'C324112183', 'newbalanceOrig': 0.0, 'nameDest': 'C288665596', 'newbalanceDest': 8496.61, '_id': ObjectId('6691111be44630bf9f92c75a')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 139054.95, 'nameOrig': 'C2092709730', 'newbalanceOrig': 0.0, 'nameDest': 'C1749186397', 'newbalanceDest': 277515.05, '_id': ObjectId('66911120e44630bf9f92c75b')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 154716.2, 'nameOrig': 'C980364771', 'newbalanceOrig': 0.0, 'nameDest': 'C453211571', 'newbalanceDest': 3461666.05, '_id': ObjectId('66911125e44630bf9f92c75c')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 53631.83, 'nameOrig': 'C1233595751', 'newbalanceOrig': 0.0, 'nameDest': 'C757108857', 'newbalanceDest': 0.0, '_id': ObjectId('6691112ae44630bf9f92c75d')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 289645.52, 'nameOrig': 'C1446001495', 'newbalanceOrig': 0.0, 'nameDest': 'C1023714065', 'newbalanceDest': 1412484.09, '_id': ObjectId('6691112fe44630bf9f92c75e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 267148.82, 'nameOrig': 'C1261044180', 'newbalanceOrig': 0.0, 'nameDest': 'C401424608', 'newbalanceDest': 1178808.14, '_id': ObjectId('66911134e44630bf9f92c75f')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 47913.58, 'nameOrig': 'C141110631', 'newbalanceOrig': 0.0, 'nameDest': 'C240650537', 'newbalanceDest': 0.0, '_id': ObjectId('66911139e44630bf9f92c760')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 193605.38, 'nameOrig': 'C2029372696', 'newbalanceOrig': 0.0, 'nameDest': 'C1971489295', 'newbalanceDest': 0.0, '_id': ObjectId('6691113ee44630bf9f92c761')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 344464.4, 'nameOrig': 'C793293778', 'newbalanceOrig': 0.0, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('66911143e44630bf9f92c762')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 169409.87, 'nameOrig': 'C888611662', 'newbalanceOrig': 0.0, 'nameDest': 'C401424608', 'newbalanceDest': 1178808.14, '_id': ObjectId('66911148e44630bf9f92c763')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 25793.74, 'nameOrig': 'C1966355106', 'newbalanceOrig': 0.0, 'nameDest': 'C476800120', 'newbalanceDest': 49864.36, '_id': ObjectId('6691114de44630bf9f92c764')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 114712.48, 'nameOrig': 'C599782425', 'newbalanceOrig': 0.0, 'nameDest': 'C1209271652', 'newbalanceDest': 0.0, '_id': ObjectId('66911152e44630bf9f92c765')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 89038.75, 'nameOrig': 'C1233327519', 'newbalanceOrig': 0.0, 'nameDest': 'C2083562754', 'newbalanceDest': 1186556.81, '_id': ObjectId('66911157e44630bf9f92c766')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 1341.58, 'nameOrig': 'C1155769010', 'newbalanceOrig': 0.0, 'nameDest': 'C557041912', 'newbalanceDest': 557537.26, '_id': ObjectId('6691115ce44630bf9f92c767')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 44443.08, 'nameOrig': 'C269892014', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66911161e44630bf9f92c768')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 34729.64, 'nameOrig': 'C1280641161', 'newbalanceOrig': 0.0, 'nameDest': 'C1435804085', 'newbalanceDest': 96.88, '_id': ObjectId('66911166e44630bf9f92c769')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 105979.34, 'nameOrig': 'C489411441', 'newbalanceOrig': 0.0, 'nameDest': 'C736709391', 'newbalanceDest': 46820.71, '_id': ObjectId('6691116be44630bf9f92c76a')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 57794.61, 'nameOrig': 'C1141113940', 'newbalanceOrig': 0.0, 'nameDest': 'C240650537', 'newbalanceDest': 0.0, '_id': ObjectId('66911170e44630bf9f92c76b')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 15918.79, 'nameOrig': 'C1711185459', 'newbalanceOrig': 0.0, 'nameDest': 'C1854778591', 'newbalanceDest': 0.0, '_id': ObjectId('66911176e44630bf9f92c76c')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 19162.08, 'nameOrig': 'C25936709', 'newbalanceOrig': 0.0, 'nameDest': 'C885951223', 'newbalanceDest': 215851.28, '_id': ObjectId('6691117be44630bf9f92c76d')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 220691.42, 'nameOrig': 'C1123559518', 'newbalanceOrig': 0.0, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66911180e44630bf9f92c76e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 9536.54, 'nameOrig': 'C649769713', 'newbalanceOrig': 0.0, 'nameDest': 'C1060830840', 'newbalanceDest': 130747.56, '_id': ObjectId('66911185e44630bf9f92c76f')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 29784.06, 'nameOrig': 'C925150995', 'newbalanceOrig': 0.0, 'nameDest': 'C920011586', 'newbalanceDest': 0.0, '_id': ObjectId('6691118ae44630bf9f92c770')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 190445.51, 'nameOrig': 'C1760219993', 'newbalanceOrig': 0.0, 'nameDest': 'C1360767589', 'newbalanceDest': 2107965.39, '_id': ObjectId('6691118fe44630bf9f92c771')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 57279.11, 'nameOrig': 'C1800649922', 'newbalanceOrig': 0.0, 'nameDest': 'C824009085', 'newbalanceDest': 64106.18, '_id': ObjectId('66911194e44630bf9f92c772')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 112086.81, 'nameOrig': 'C403547747', 'newbalanceOrig': 0.0, 'nameDest': 'C1531333864', 'newbalanceDest': 55974.56, '_id': ObjectId('66911199e44630bf9f92c773')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 80311.89, 'nameOrig': 'C172215878', 'newbalanceOrig': 0.0, 'nameDest': 'C434091818', 'newbalanceDest': 63112.23, '_id': ObjectId('6691119ee44630bf9f92c774')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 151829.91, 'nameOrig': 'C873309260', 'newbalanceOrig': 0.0, 'nameDest': 'C1023714065', 'newbalanceDest': 1412484.09, '_id': ObjectId('669111a3e44630bf9f92c775')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 26004.52, 'nameOrig': 'C1112456099', 'newbalanceOrig': 0.0, 'nameDest': 'C1225616405', 'newbalanceDest': 0.0, '_id': ObjectId('669111a8e44630bf9f92c776')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 3146.16, 'nameOrig': 'C923083575', 'newbalanceOrig': 0.0, 'nameDest': 'C1504109395', 'newbalanceDest': 593737.38, '_id': ObjectId('669111ade44630bf9f92c777')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 296752.75, 'nameOrig': 'C589363823', 'newbalanceOrig': 0.0, 'nameDest': 'C1531333864', 'newbalanceDest': 55974.56, '_id': ObjectId('669111b2e44630bf9f92c778')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 191702.06, 'nameOrig': 'C2052457859', 'newbalanceOrig': 0.0, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('669111b7e44630bf9f92c779')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 365510.05, 'nameOrig': 'C1299327689', 'newbalanceOrig': 0.0, 'nameDest': 'C564160838', 'newbalanceDest': 1254956.07, '_id': ObjectId('669111bce44630bf9f92c77a')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 202332.08, 'nameOrig': 'C1408279755', 'newbalanceOrig': 0.0, 'nameDest': 'C453211571', 'newbalanceDest': 3461666.05, '_id': ObjectId('669111c1e44630bf9f92c77b')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 55105.9, 'nameOrig': 'C2007486296', 'newbalanceOrig': 0.0, 'nameDest': 'C932583850', 'newbalanceDest': 2719172.89, '_id': ObjectId('669111c6e44630bf9f92c77c')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 171508.59, 'nameOrig': 'C1033348658', 'newbalanceOrig': 0.0, 'nameDest': 'C1971489295', 'newbalanceDest': 0.0, '_id': ObjectId('669111cbe44630bf9f92c77d')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 178439.26, 'nameOrig': 'C1634723627', 'newbalanceOrig': 0.0, 'nameDest': 'C2083562754', 'newbalanceDest': 1186556.81, '_id': ObjectId('669111d0e44630bf9f92c77e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 88834.86, 'nameOrig': 'C938463537', 'newbalanceOrig': 0.0, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('669111d5e44630bf9f92c77f')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 210370.09, 'nameOrig': 'C2121995675', 'newbalanceOrig': 0.0, 'nameDest': 'C1170794006', 'newbalanceDest': 22190.99, '_id': ObjectId('669111dae44630bf9f92c780')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 36437.06, 'nameOrig': 'C2120063568', 'newbalanceOrig': 0.0, 'nameDest': 'C1740000325', 'newbalanceDest': 1363368.51, '_id': ObjectId('669111dfe44630bf9f92c781')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 82691.56, 'nameOrig': 'C1620409359', 'newbalanceOrig': 0.0, 'nameDest': 'C248609774', 'newbalanceDest': 6453430.91, '_id': ObjectId('669111e4e44630bf9f92c782')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 338767.1, 'nameOrig': 'C691691381', 'newbalanceOrig': 0.0, 'nameDest': 'C453211571', 'newbalanceDest': 3461666.05, '_id': ObjectId('669111e9e44630bf9f92c783')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 187728.59, 'nameOrig': 'C264978436', 'newbalanceOrig': 0.0, 'nameDest': 'C1360767589', 'newbalanceDest': 2107965.39, '_id': ObjectId('669111eee44630bf9f92c784')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 271002.7, 'nameOrig': 'C500618423', 'newbalanceOrig': 0.0, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('669111f3e44630bf9f92c785')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 323105.08, 'nameOrig': 'C1458091526', 'newbalanceOrig': 0.0, 'nameDest': 'C747464370', 'newbalanceDest': 1567434.81, '_id': ObjectId('669111f8e44630bf9f92c786')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 10782.94, 'nameOrig': 'C768776793', 'newbalanceOrig': 0.0, 'nameDest': 'C796533847', 'newbalanceDest': 0.0, '_id': ObjectId('669111fde44630bf9f92c787')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 89962.11, 'nameOrig': 'C2018260103', 'newbalanceOrig': 0.0, 'nameDest': 'C240650537', 'newbalanceDest': 0.0, '_id': ObjectId('66911202e44630bf9f92c788')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 101940.14, 'nameOrig': 'C1393828949', 'newbalanceOrig': 0.0, 'nameDest': 'C357863579', 'newbalanceDest': 92307.65, '_id': ObjectId('66911207e44630bf9f92c789')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 163100.34, 'nameOrig': 'C1088417975', 'newbalanceOrig': 0.0, 'nameDest': 'C401424608', 'newbalanceDest': 1178808.14, '_id': ObjectId('6691120ce44630bf9f92c78a')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 136030.66, 'nameOrig': 'C2036775591', 'newbalanceOrig': 0.0, 'nameDest': 'C757108857', 'newbalanceDest': 0.0, '_id': ObjectId('66911211e44630bf9f92c78b')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 68912.23, 'nameOrig': 'C1620529408', 'newbalanceOrig': 0.0, 'nameDest': 'C1688019098', 'newbalanceDest': 97263.78, '_id': ObjectId('66911216e44630bf9f92c78c')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 73464.06, 'nameOrig': 'C307488715', 'newbalanceOrig': 0.0, 'nameDest': 'C1789550256', 'newbalanceDest': 4619798.56, '_id': ObjectId('6691121be44630bf9f92c78d')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 106117.28, 'nameOrig': 'C758572926', 'newbalanceOrig': 0.0, 'nameDest': 'C476402209', 'newbalanceDest': 51513.44, '_id': ObjectId('66911220e44630bf9f92c78e')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 503333.79, 'nameOrig': 'C1640612861', 'newbalanceOrig': 0.0, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('66911225e44630bf9f92c78f')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 71991.42, 'nameOrig': 'C990679445', 'newbalanceOrig': 0.0, 'nameDest': 'C557041912', 'newbalanceDest': 557537.26, '_id': ObjectId('6691122ae44630bf9f92c790')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 91379.93, 'nameOrig': 'C913065088', 'newbalanceOrig': 0.0, 'nameDest': 'C401424608', 'newbalanceDest': 1178808.14, '_id': ObjectId('6691122fe44630bf9f92c791')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 26759.05, 'nameOrig': 'C746280996', 'newbalanceOrig': 0.0, 'nameDest': 'C1360767589', 'newbalanceDest': 2107965.39, '_id': ObjectId('66911234e44630bf9f92c792')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 128487.35, 'nameOrig': 'C50503805', 'newbalanceOrig': 0.0, 'nameDest': 'C747464370', 'newbalanceDest': 1567434.81, '_id': ObjectId('66911239e44630bf9f92c793')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 252908.87, 'nameOrig': 'C1557989809', 'newbalanceOrig': 0.0, 'nameDest': 'C33524623', 'newbalanceDest': 1517262.16, '_id': ObjectId('6691123ee44630bf9f92c794')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 64489.64, 'nameOrig': 'C146874094', 'newbalanceOrig': 0.0, 'nameDest': 'C1297685781', 'newbalanceDest': 16997.22, '_id': ObjectId('66911243e44630bf9f92c795')}
# Inserted record: {'step': 1, 'type': 'CASH_OUT', 'amount': 171369.73, 'nameOrig': 'C2123222442', 'newbalanceOrig': 0.0, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('66911248e44630bf9f92c796')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 4493.29, 'nameOrig': 'C1746570062', 'newbalanceOrig': 3764.71, 'nameDest': 'M1555990397', 'newbalanceDest': 0.0, '_id': ObjectId('6691124de44630bf9f92c797')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 12121.5, 'nameOrig': 'C1544078442', 'newbalanceOrig': 84936.5, 'nameDest': 'M1291367132', 'newbalanceDest': 0.0, '_id': ObjectId('66911252e44630bf9f92c798')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 2278.19, 'nameOrig': 'C1887699190', 'newbalanceOrig': 0.0, 'nameDest': 'M1479140596', 'newbalanceDest': 0.0, '_id': ObjectId('66911257e44630bf9f92c799')}
# ...
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 106634.77, 'nameOrig': 'C1660223291', 'newbalanceOrig': 1080930.07, 'nameDest': 'C1170794006', 'newbalanceDest': 22190.99, '_id': ObjectId('669116d5e44630bf9f92c87f')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 74933.22, 'nameOrig': 'C379124840', 'newbalanceOrig': 1155863.3, 'nameDest': 'C1023714065', 'newbalanceDest': 1412484.09, '_id': ObjectId('669116dae44630bf9f92c880')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 120234.99, 'nameOrig': 'C1157943921', 'newbalanceOrig': 1276098.29, 'nameDest': 'C977993101', 'newbalanceDest': 965870.05, '_id': ObjectId('669116dfe44630bf9f92c881')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 5763.99, 'nameOrig': 'C544966217', 'newbalanceOrig': 1281862.28, 'nameDest': 'C1870252780', 'newbalanceDest': 46462.23, '_id': ObjectId('669116e4e44630bf9f92c882')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 156922.36, 'nameOrig': 'C1706272858', 'newbalanceOrig': 1438784.65, 'nameDest': 'C665576141', 'newbalanceDest': 5515763.34, '_id': ObjectId('669116e9e44630bf9f92c883')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 162665.98, 'nameOrig': 'C882471736', 'newbalanceOrig': 1601450.63, 'nameDest': 'C1096283470', 'newbalanceDest': 0.0, '_id': ObjectId('669116eee44630bf9f92c884')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 110226.34, 'nameOrig': 'C1475192960', 'newbalanceOrig': 1601450.63, 'nameDest': 'C1816757085', 'newbalanceDest': 10681238.79, '_id': ObjectId('669116f3e44630bf9f92c885')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 142577.44, 'nameOrig': 'C727197178', 'newbalanceOrig': 1744028.07, 'nameDest': 'C1100439041', 'newbalanceDest': 0.0, '_id': ObjectId('669116f8e44630bf9f92c886')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 6915.38, 'nameOrig': 'C1406253491', 'newbalanceOrig': 1750943.45, 'nameDest': 'C85777802', 'newbalanceDest': 0.0, '_id': ObjectId('669116fde44630bf9f92c887')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 157108.01, 'nameOrig': 'C749604930', 'newbalanceOrig': 1908051.46, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('66911702e44630bf9f92c888')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 223555.14, 'nameOrig': 'C373097727', 'newbalanceOrig': 2131606.6, 'nameDest': 'C564160838', 'newbalanceDest': 1254956.07, '_id': ObjectId('66911707e44630bf9f92c889')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 146331.12, 'nameOrig': 'C2082509879', 'newbalanceOrig': 2277937.72, 'nameDest': 'C1531333864', 'newbalanceDest': 55974.56, '_id': ObjectId('6691170ce44630bf9f92c88a')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 141131.23, 'nameOrig': 'C576894497', 'newbalanceOrig': 2419068.96, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('66911711e44630bf9f92c88b')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 222711.47, 'nameOrig': 'C2123533871', 'newbalanceOrig': 2641780.43, 'nameDest': 'C1590550415', 'newbalanceDest': 19169204.93, '_id': ObjectId('66911716e44630bf9f92c88c')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 84980.31, 'nameOrig': 'C16148478', 'newbalanceOrig': 2726760.74, 'nameDest': 'C1335050193', 'newbalanceDest': 353532.56, '_id': ObjectId('6691171be44630bf9f92c88d')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 628719.07, 'nameOrig': 'C2022689531', 'newbalanceOrig': 3355479.81, 'nameDest': 'C1359044626', 'newbalanceDest': 16518.36, '_id': ObjectId('66911720e44630bf9f92c88e')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 79285.8, 'nameOrig': 'C1340848245', 'newbalanceOrig': 3434765.61, 'nameDest': 'C1170794006', 'newbalanceDest': 22190.99, '_id': ObjectId('66911725e44630bf9f92c88f')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 57809.81, 'nameOrig': 'C635610193', 'newbalanceOrig': 3492575.42, 'nameDest': 'C1454031203', 'newbalanceDest': 0.0, '_id': ObjectId('6691172ae44630bf9f92c890')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 75043.17, 'nameOrig': 'C379121284', 'newbalanceOrig': 3567618.59, 'nameDest': 'C1511785794', 'newbalanceDest': 0.0, '_id': ObjectId('6691172fe44630bf9f92c891')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 248196.92, 'nameOrig': 'C281421502', 'newbalanceOrig': 3815815.51, 'nameDest': 'C1297685781', 'newbalanceDest': 16997.22, '_id': ObjectId('66911734e44630bf9f92c892')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 18851.44, 'nameOrig': 'C50072771', 'newbalanceOrig': 3834666.95, 'nameDest': 'C215145189', 'newbalanceDest': 1891.79, '_id': ObjectId('66911739e44630bf9f92c893')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 403418.39, 'nameOrig': 'C848097505', 'newbalanceOrig': 4238085.34, 'nameDest': 'C1286084959', 'newbalanceDest': 2107778.11, '_id': ObjectId('6691173ee44630bf9f92c894')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 235564.81, 'nameOrig': 'C1672598778', 'newbalanceOrig': 4473650.15, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('66911743e44630bf9f92c895')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 32325.24, 'nameOrig': 'C1122233828', 'newbalanceOrig': 4505975.39, 'nameDest': 'C1068824137', 'newbalanceDest': 265092.36, '_id': ObjectId('66911748e44630bf9f92c896')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 345347.7, 'nameOrig': 'C538667887', 'newbalanceOrig': 4851323.08, 'nameDest': 'C240650537', 'newbalanceDest': 0.0, '_id': ObjectId('6691174de44630bf9f92c897')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 355500.25, 'nameOrig': 'C1967496309', 'newbalanceOrig': 5206823.33, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('66911752e44630bf9f92c898')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 103005.78, 'nameOrig': 'C406749219', 'newbalanceOrig': 5309829.12, 'nameDest': 'C716157500', 'newbalanceDest': 4894.45, '_id': ObjectId('66911757e44630bf9f92c899')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 108803.98, 'nameOrig': 'C1173340685', 'newbalanceOrig': 5418633.09, 'nameDest': 'C766572210', 'newbalanceDest': 0.0, '_id': ObjectId('6691175ce44630bf9f92c89a')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 259753.27, 'nameOrig': 'C1045731788', 'newbalanceOrig': 5678386.36, 'nameDest': 'C1209271652', 'newbalanceDest': 0.0, '_id': ObjectId('66911761e44630bf9f92c89b')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 234094.24, 'nameOrig': 'C1739267143', 'newbalanceOrig': 5912480.6, 'nameDest': 'C985934102', 'newbalanceDest': 971418.91, '_id': ObjectId('66911766e44630bf9f92c89c')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 273305.73, 'nameOrig': 'C192456457', 'newbalanceOrig': 6185786.33, 'nameDest': 'C1023714065', 'newbalanceDest': 1412484.09, '_id': ObjectId('6691176be44630bf9f92c89d')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 186838.95, 'nameOrig': 'C817689537', 'newbalanceOrig': 6372625.28, 'nameDest': 'C736709391', 'newbalanceDest': 46820.71, '_id': ObjectId('66911770e44630bf9f92c89e')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 193161.04, 'nameOrig': 'C708613859', 'newbalanceOrig': 6565786.32, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('66911775e44630bf9f92c89f')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 152823.85, 'nameOrig': 'C365625031', 'newbalanceOrig': 6718610.17, 'nameDest': 'C1789550256', 'newbalanceDest': 4619798.56, '_id': ObjectId('6691177ae44630bf9f92c8a0')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 91457.82, 'nameOrig': 'C1531200408', 'newbalanceOrig': 6810067.99, 'nameDest': 'C1509514333', 'newbalanceDest': 2415.16, '_id': ObjectId('6691177fe44630bf9f92c8a1')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 277807.48, 'nameOrig': 'C212963786', 'newbalanceOrig': 7087875.47, 'nameDest': 'C1531333864', 'newbalanceDest': 55974.56, '_id': ObjectId('66911784e44630bf9f92c8a2')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 8679.13, 'nameOrig': 'C1123321137', 'newbalanceOrig': 7096554.61, 'nameDest': 'C575335780', 'newbalanceDest': 52415.15, '_id': ObjectId('6691178ae44630bf9f92c8a3')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 2099.59, 'nameOrig': 'C685934', 'newbalanceOrig': 7098654.2, 'nameDest': 'C1854778591', 'newbalanceDest': 0.0, '_id': ObjectId('6691178fe44630bf9f92c8a4')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 221693.08, 'nameOrig': 'C2032909428', 'newbalanceOrig': 7320347.28, 'nameDest': 'C1531333864', 'newbalanceDest': 55974.56, '_id': ObjectId('66911794e44630bf9f92c8a5')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 206097.65, 'nameOrig': 'C2031377754', 'newbalanceOrig': 7526444.93, 'nameDest': 'C564160838', 'newbalanceDest': 1254956.07, '_id': ObjectId('66911799e44630bf9f92c8a6')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 22384.21, 'nameOrig': 'C523211332', 'newbalanceOrig': 7548829.13, 'nameDest': 'C459857341', 'newbalanceDest': 387263.02, '_id': ObjectId('6691179ee44630bf9f92c8a7')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 73210.99, 'nameOrig': 'C1280124872', 'newbalanceOrig': 7622040.12, 'nameDest': 'C1435804085', 'newbalanceDest': 96.88, '_id': ObjectId('669117a3e44630bf9f92c8a8')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 236747.6, 'nameOrig': 'C1747053097', 'newbalanceOrig': 7858787.73, 'nameDest': 'C757108857', 'newbalanceDest': 0.0, '_id': ObjectId('669117a8e44630bf9f92c8a9')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 6284.18, 'nameOrig': 'C864326906', 'newbalanceOrig': 7865071.9, 'nameDest': 'C1749186397', 'newbalanceDest': 277515.05, '_id': ObjectId('669117ade44630bf9f92c8aa')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 100198.77, 'nameOrig': 'C1348115836', 'newbalanceOrig': 7965270.68, 'nameDest': 'C1750905143', 'newbalanceDest': 424250.45, '_id': ObjectId('669117b2e44630bf9f92c8ab')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 160347.32, 'nameOrig': 'C1972143064', 'newbalanceOrig': 8125617.99, 'nameDest': 'C33524623', 'newbalanceDest': 1517262.16, '_id': ObjectId('669117b7e44630bf9f92c8ac')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 289272.75, 'nameOrig': 'C312168418', 'newbalanceOrig': 8414890.75, 'nameDest': 'C75457651', 'newbalanceDest': 31469.78, '_id': ObjectId('669117bce44630bf9f92c8ad')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 63189.26, 'nameOrig': 'C95369743', 'newbalanceOrig': 8478080.0, 'nameDest': 'C1860513229', 'newbalanceDest': 0.0, '_id': ObjectId('669117c1e44630bf9f92c8ae')}
# Inserted record: {'step': 1, 'type': 'CASH_IN', 'amount': 196725.32, 'nameOrig': 'C26928827', 'newbalanceOrig': 8674805.32, 'nameDest': 'C451111351', 'newbalanceDest': 3940085.21, '_id': ObjectId('669117c6e44630bf9f92c8af')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5882.32, 'nameOrig': 'C278476563', 'newbalanceOrig': 4369.68, 'nameDest': 'M1479909053', 'newbalanceDest': 0.0, '_id': ObjectId('669117cbe44630bf9f92c8b0')}
# Inserted record: {'step': 1, 'type': 'DEBIT', 'amount': 625.92, 'nameOrig': 'C615954678', 'newbalanceOrig': 29539.08, 'nameDest': 'C811587677', 'newbalanceDest': 0.0, '_id': ObjectId('669117d0e44630bf9f92c8b1')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 5937.72, 'nameOrig': 'C1926180325', 'newbalanceOrig': 15841.28, 'nameDest': 'M733461760', 'newbalanceDest': 0.0, '_id': ObjectId('669117d5e44630bf9f92c8b2')}
# Inserted record: {'step': 1, 'type': 'PAYMENT', 'amount': 9796.29, 'nameOrig': 'C1594039997', 'newbalanceOrig': 264861.71, 'nameDest': 'M1323531427', 'newbalanceDest': 0.0, '_id': ObjectId('669117dae44630bf9f92c8b3')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 22
#      19 consumer = KafkaConsumer("ftde01-project4", bootstrap_servers="localhost")
#      20 print("Starting the consumer")
# ---> 22 for msg in consumer:
#      23     data = json.loads(msg.value)
#      24     if isinstance(data, list):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
# MERGING DATA FROM MONGO DB THAT STORES DATA CATHCED FROM KAFKA CONSUMER WITH DATA FROM POSTGRESQL

# %%
# !pip install pandas sqlalchemy pymongo psycopg2-binary
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: sqlalchemy in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (1.4.52)
# Requirement already satisfied: pymongo in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (4.7.3)
# Requirement already satisfied: psycopg2-binary in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.9.9)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.0.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import library needed

import pandas as pd
from sqlalchemy import create_engine
from pymongo import MongoClient

# %%
# MongoDB connection
client = MongoClient(("mongodb://admin:admin@localhost:27017/"))
mongo_db = client["kafka_consumer_data_01"]
mongo_collection = mongo_db['kafka_consumer_collection_01']

# PostgreSQL connection
pg_engine = create_engine('postgresql://postgres:admin@localhost:5432/project_stream_processing')

# Fetch data from MongoDB
mongo_data = pd.DataFrame(list(mongo_collection.find()))

# Fetch data from PostgreSQL
pg_data = pd.read_sql_table('old_information', pg_engine)

# Merge data (data will be merged on 'nameOrig' and'nameDest')
merged_data = pd.merge(mongo_data, pg_data, on=['nameOrig','nameDest'])

# test script
print(merged_data.head(3))
# Out:
#                         _id  step      type   amount     nameOrig  \
# 0  66910e0ae44630bf9f92c6bd     1   PAYMENT  9839.64  C1231006815
# 1  66910e0fe44630bf9f92c6be     1   PAYMENT  1864.28  C1666544295
# 2  66910e14e44630bf9f92c6bf     1  TRANSFER   181.00  C1305486145
#
#    newbalanceOrig     nameDest  newbalanceDest  oldbalanceOrg  oldbalanceDest
# 0       160296.36  M1979787155             0.0       170136.0             0.0
# 1        19384.72  M2044282225             0.0        21249.0             0.0
# 2            0.00   C553264065             0.0          181.0             0.0

# %%
# RUNNING THE MODEL ON THE DATA MERGED FROM BOTH DATABASE

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')

# %%
from modelling import FraudModel

# %%
import os

path = os.getcwd()
path = path + "\\modelling\\"
path
# Out:
# 'D:\\project_4_FTDE_fraud_detection\\modelling\\'

# %%
# Initialize an empty list to collect results
results = []

# Loop through each row in merged_data
for idx, row in merged_data.iterrows():
    # Convert the row to a dictionary
    predict = row.drop(['nameOrig', 'nameDest']).to_dict()
    # Run the model
    result = FraudModel.runModel(predict, path)
    # Append the result to the list
    results.append(result)

# %%
print(results)
# Out:
# ['White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White List', 'White Li ...

# %%
# Convert results to DataFrame
result_df = pd.DataFrame(results, index=merged_data.index)

# Rename the result column to 'predictionResult'
result_df.columns = ['predictionResult']

# Combine result with merged_data
final_data = merged_data.join(result_df, how='left')

# %%
# Print final data to verify

print(final_data.head(5))
final_data.columns
# Out:
#                         _id  step      type    amount     nameOrig  \
# 0  66910e0ae44630bf9f92c6bd     1   PAYMENT   9839.64  C1231006815
# 1  66910e0fe44630bf9f92c6be     1   PAYMENT   1864.28  C1666544295
# 2  66910e14e44630bf9f92c6bf     1  TRANSFER    181.00  C1305486145
# 3  66910e19e44630bf9f92c6c0     1  CASH_OUT    181.00   C840083671
# 4  66910e1ee44630bf9f92c6c1     1   PAYMENT  11668.14  C2048537720
#
#    newbalanceOrig     nameDest  newbalanceDest  oldbalanceOrg  oldbalanceDest  \
# 0       160296.36  M1979787155             0.0       170136.0             0.0
# 1        19384.72  M2044282225             0.0        21249.0             0.0
# 2            0.00   C553264065             0.0          181.0             0.0
# 3            0.00    C38997010             0.0          181.0         21182.0
# 4        29885.86  M1230701703             0.0        41554.0             0.0
#
#   predictionResult
# 0       White List
# 1       White List
# 2       White List
# 3       White List
# 4       White List
# Index(['_id', 'step', 'type', 'amount', 'nameOrig', 'newbalanceOrig',
#        'nameDest', 'newbalanceDest', 'oldbalanceOrg', 'oldbalanceDest',
#        'predictionResult'],
#       dtype='object')

# %%
# CONVERTING DATA OF PREDICTION RESULT FROM DATA FRAME TO DICTIONARY AND INGEST TO MONGO DB AGAIN

# %%
from pymongo import MongoClient
mongo_client = MongoClient("mongodb://admin:admin@localhost:27017/")
db = mongo_client["project4_model_result_01"]
collection = db["project4_model_result_coll_01"]

# Convert the entire DataFrame to a list of dictionaries
data_dict = final_data.to_dict('records')

# Insert the data into MongoDB
collection.insert_many(data_dict)
print("Data stored to MongoDB")
# Out:
# Data stored to MongoDB
